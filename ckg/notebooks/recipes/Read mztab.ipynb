# %%
from ckg.graphdb_builder import builder_utils

# %%
example_file = 'tmp/example_PXD022733.mzTab'

# %%
data = builder_utils.parse_mztab_file(example_file)

# %%
print(data.keys())
# Out:
# dict_keys(['MTD', 'PRT', 'PSM'])

# %%
data['PRT'].head()
# Out:
#     accession                                        description taxid  \
# 0  A0A075B6I9  sp|A0A075B6I9|LV746_HUMAN Immunoglobulin lambd...  null
# 1  A0A075B6K5  sp|A0A075B6K5|LV39_HUMAN Immunoglobulin lambda...  null
# 2  A0A075B6P5  sp|A0A075B6P5|KV228_HUMAN Immunoglobulin kappa...  null
# 3  A0A0C4DH67  sp|A0A0C4DH67|KV108_HUMAN Immunoglobulin kappa...  null
# 4  A0A0A0MRZ8  sp|A0A0A0MRZ8|KVD11_HUMAN Immunoglobulin kappa...  null
#
#   species database database_version                         search_engine  \
# 0    null     null             null  [MS, MS:1002337, Andromeda, 1.6.8.0]
# 1    null     null             null  [MS, MS:1002337, Andromeda, 1.6.8.0]
# 2    null     null             null  [MS, MS:1002337, Andromeda, 1.6.8.0]
# 3    null     null             null  [MS, MS:1002337, Andromeda, 1.6.8.0]
# 4    null     null             null  [MS, MS:1002337, Andromeda, 1.6.8.0]
#
#   best_search_engine_score[1] search_engine_score[1]_ms_run[1]  \
# 0            2.54172068110967                             null
# 1            12.3898963082584                             null
# 2            37.2781261617028                             null
# 3            2.75929244987718                             null
# 4            10.1196640910864                             null
#
#   search_engine_score[1]_ms_run[2]  ... num_peptides_unique_ms_run[254]  \
# 0                             null  ...                            null
# 1                             null  ...                            null
# 2                             null  ...                            null
# 3                             null  ...                            null
# 4                             null  ...                            null
#
#   num_peptides_unique_ms_run[255] num_peptides_unique_ms_run[256]  \
# 0                            null                            null
# 1                            null                            null
# 2                            null                            null
# 3                            null                            null
# 4                            null                            null
#
#   num_peptides_unique_ms_run[257] num_peptides_unique_ms_run[258]  \
# 0                            null                            null
# 1                            null                            null
# 2                            null                            null
# 3                            null                            null
# 4                            null                            null
#
#   num_peptides_unique_ms_run[259]  \
# 0                            null
# 1                            null
# 2                            null
# 3                            null
# 4                            null
#
#                                    ambiguity_members modifications  \
# 0                                 A0A075B6I9, P04211          null
# 1                                 A0A075B6K5, P80748          null
# 2  A0A075B6P5, A0A087WW87, P01615, P01614, A2NJV5...          null
# 3                 A0A0C4DH67, A0A0C4DH69, A0A075B6S5          null
# 4                                 A0A0A0MRZ8, P04433          null
#
#   protein_coverage opt_global_cv_MS:1002217_decoy_peptide
# 0            0.137                                      0
# 1            0.139                                      0
# 2            0.167                                      0
# 3            0.139                                      0
# 4            0.322                                      0
#
# [5 rows x 1048 columns]
