# %%
import pandas as pd

def readDataset(uri):
    if uri.endswith('.xlsx'):
        data = readDataFromExcel(uri)
    elif uri.endswith(".csv") or uri.endswith(".tsv") or uri.endswith(".txt"):
        if uri.endswith(".tsv") or uri.endswith(".txt"):
            data = readDataFromTXT(uri)
        else:
            data = readDataFromCSV(uri)

    return data

def readDataFromExcel(uri):
    #Read the data from Excel file
    data = pd.read_excel(open(uri), index_col=None, na_values=['NA'])

    return data

def parseClinicalDataset(uri):
    '''This function parses clinical data from subjects in the project
    Input: uri of the clinical data file. Format: Subjects as rows, clinical variables as columns
    Output: pandas DataFrame with the same input format but the clinical variables mapped to the
    right ontology (defined in config), i.e. type = -40 -> SNOMED CT'''
    data = readDataset(uri)
    data = data.set_index("sample id")
    cols = list(data.columns)
    if "group" in data.columns:
        cols.remove("group")
        data = data[cols]
    data = data.stack()
    data = data.reset_index()
    data[':TYPE'] = ""
    data.columns = [':START_ID(Sample)', ':END_ID(Clinical_variable)',':TYPE', 'score']

def defineClinicalRelationships(data):
    relationships = set()

# %%
uri = '../Data/NAFLD/clinical data.xlsx'

parseClinicalDataset(uri)
# Out:
# sample id
# 31         GIGD                 50
#            glucoseinput         25
#            TaucOGTT           1599
#            TaucIGII           1639
#            FPG                   5
#            HbA1c                37
#            BMI                  29
#            waist               113
#            Platelets           244
#            Bili                  9
#            alb                  44
#            ALAT                 30
#            ASAT                 24
#            BP                   66
#            GTT                  58
#            chol                  6
#            HDL                   2
#            LDL                   4
#            TG                    2
#            glucagon              5
#            AA              1048.76
# 32         GIGD                 34
#            glucoseinput         33
#            TaucOGTT           1494
#            TaucIGII           1523
#            FPG                   4
#            HbA1c                36
#            BMI                  28
#            waist                97
#            Platelets           313
#                             ...
# 77         ASAT                 64
#            BP                  260
#            GTT                 142
#            chol                  4
#            HDL                   2
#            LDL                   1
#            TG                    1
#            glucagon              7
#            AA              895.725
# 78         GIGD                 24
#            glucoseinput         38
#            TaucOGTT           2440
#            TaucIGII           2392
#            FPG                   5
#            HbA1c                40
#            BMI                  24
#            waist                94
#            Platelets           136
#            Bili                 15
#            alb                  38
#            ALAT                 46
#            ASAT                 52
#            BP                   64
#            GTT                  55
#            chol                  4
#            HDL                   2
#            LDL                   2
#            TG                    2
#            glucagon             25
#            AA              1332.15
# Length: 1018, dtype: object
