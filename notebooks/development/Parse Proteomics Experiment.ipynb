# %%
import pandas as pd
from collections import defaultdict
import numpy as np
import sys


proteomicsDataColumns = ["Majority protein IDs", 
                        "Gene names", "Q-value", 
                        "Score", 
                        "Intensity \d+_\d+", 
                        "LFQ intensity \d+_\d+", 
                        "Glycation site positions", 
                        "Glycation site positions",
                        "Reverse",
                        "Potential contaminant",
                        "Only identified by site"]

proteomicsDataFilters = ["Reverse",
                       "Potential contaminant",
                       "Only identified by site"]

proteomicsDataProteinCol = "Majority protein IDs"

proteomicsDataGeneCol = "Gene names"
proteomicsDataModPosCol = ["Glycation site positions", "Oxidation (M) site positions"]
proteomicsDataLog = "log10"

def loadProteomicsDataset(uri):
    ''' This function gets the molecular data from a proteomics experiment.
        Input: uri of the processed file resulting from MQ
        Output: pandas DataFrame with the columns and filters defined in config.py '''

    aux = None
    
    #Get the columns from config and divide them into simple or regex columns
    columns = proteomicsDataColumns
    regexCols = [c for c in columns if '+' in c]
    columns = set(columns).difference(regexCols)
        
    #Read the filters defined in config, i.e. reverse, contaminant, etc.
    filters = proteomicsDataFilters
    proteinCol = proteomicsDataProteinCol
    geneCol = proteomicsDataGeneCol
    modPosCol = proteomicsDataModPosCol
    
    
    #Read the data from file
    data = pd.read_csv(uri, sep = '\t', low_memory=False)

    #Apply filters
    data = data[data[filters].isnull().any(1)]
    data = data.drop(filters, axis=1)
    
    #Select first protein form group, i.e. P01911;Q29830;Q9MXZ4 -> P01911
    #Set protein as index
    proteins = data[proteinCol].str.split(';').apply(pd.Series,1)[0]
    data[proteinCol] = proteins
    data = data.set_index(proteinCol)
    filters.append(proteinCol)
    columns = set(columns).difference(filters)
    
    #As well, select first gene name and first modification position corresponding
    #to the selected protein
    genes = data[geneCol].str.split(';').apply(pd.Series,1)[0]
    data[geneCol] = genes
    for modCol in modPosCol:
        mod = data[modCol].str.split(';').apply(pd.Series,1)[0]
        data[modCol] = mod

    #Get columns using regex
    for regex in regexCols:
        if aux is None:
            aux = data.filter(regex=regex)
        else:
            aux = aux.join(data.filter(regex=regex))

    #Add simple and regex columns into a single DataFrame
    data = data[list(columns)]
    data = data.join(aux)

    return data, regexCols

def extractSubjectReplicates(data, regex):
    subjectDict = defaultdict(list)
    for r in regex:
        columns = data.filter(regex = r).columns
        for c in columns:
            fields  = c.split('_')
            value = " ".join(fields[0].split(' ')[0:-1])
            subject = fields[1]
            ident = value + " " + subject 
            subjectDict[ident].append(c)

    return subjectDict
            
def parseProteomicsDataset(projectID, uri):
    log = proteomicsDataLog
    data, regex = loadProteomicsDataset(uri)
    subjectDict = extractSubjectReplicates(data, regex)
    delCols = []
    for subject in subjectDict:
            delCols.extend(subjectDict[subject])
            aux = data[subjectDict[subject]]
            data[subject] = calculateMedianReplicates(aux, log)

    data = data.drop(delCols, 1)
    
    
    return data

def calculateMedianReplicates(data, log = "log2"):
    if log == "log2":
        data = data.applymap(lambda x:np.log2(x) if x > 0 else np.nan)
    elif log == "log10":
        data = data.applymap(lambda x:np.log10(x) if x > 0 else np.nan)
    median = data.median(axis=1).sort_values(axis=0, ascending= True, na_position = 'first').to_frame()
    return median


def extractProteinSubjectRelationships(data):
    aux =  data.filter(regex = 'LFQ intensity')
    aux.columns = [c.split(" ")[2] for c in aux.columns]
    aux = aux.stack()
    aux = aux.reset_index()
    aux.columns = [':START_ID(Protein)', ':END_ID(Subject)', "LFQ intensity"]
    
    return aux

#ToDo
def extractModificationProteinSubjectRelationships(data):
    subjects =  data.filter(regex = 'LFQ intensity')
    subjects.columns = [c.split(" ")[2] for c in subjects.columns]
    subjects = subjects.stack()
    subjects = subjects.reset_index()
    icol = subjects.columns[0]
    subjects.columns  = [icol, "subject id","LFQ intensity"]
    
    modPosCol = proteomicsDataModPosCol
    cols = [c for c in data.columns if c in modPosCol]
    mod =  data.filter(cols)
    mod.columns = [modPosCol[c] for c in mod.columns]
      
    return mod

# %%
data = parseProteomicsDataset(projectID = 1, uri = "../Data/NAFLD/proteinGroups.txt")

# %%
data
# Out:
#                      Glycation site positions  Gene names     Score   Q-value  \
# Majority protein IDs
# P01911                                    NaN    HLA-DRB1   11.5300  0.000000
# P05121                                    NaN    SERPINE1   83.1030  0.000000
# P55083                                    NaN       MFAP4  272.8700  0.000000
# P09972                                    NaN       ALDOC  114.8900  0.000000
# Q96C19                                    NaN       EFHD2    3.8073  0.001086
# P37198                                    NaN       NUP62    2.8480  0.002982
# Q96A32                                    NaN       MYLPF   11.9280  0.000000
# P55899                                    NaN       FCGRT    2.7262  0.003922
# P35749                                    NaN       MYH11  151.1100  0.000000
# P06493                                    NaN        CDK1    7.1382  0.000000
# A0A024QZL1                                NaN        PRG1   27.4060  0.000000
# P18206                                    NaN         VCL  323.3100  0.000000
# Q8IWL2                                    NaN      SFTPA1   35.2650  0.000000
# P07602                                    NaN        PSAP   56.9530  0.000000
# P16083                                    NaN        NQO2   19.1930  0.000000
# Q8NBS9                                    NaN      TXNDC5  215.6300  0.000000
# P35237                                    NaN    SERPINB6   10.6950  0.000000
# P33778                                    NaN   HIST1H2BB   64.5180  0.000000
# Q6FI13                                    NaN  HIST2H2AA3   67.3270  0.000000
# O15117                                    NaN         FYB   80.1970  0.000000
# P02748                                    NaN          C9  323.3100  0.000000
# Q8WVV5                                    NaN      BTN2A2    3.4066  0.001568
# Q9NS62                                    NaN       THSD1    2.5407  0.006232
# Q9BRK5                                    NaN        SDF4   10.3240  0.000000
# P09603                                    NaN        CSF1   69.4400  0.000000
# O43865                                    NaN      AHCYL1   -2.0000  1.000000
# P52907                                    NaN      CAPZA1   10.8300  0.000000
# P06731                                    NaN     CEACAM5    2.7190  0.004410
# P01137                                    NaN       TGFB1   13.2040  0.000000
# Q8IV08                                    NaN        PLD3    3.0610  0.002039
# ...                                       ...         ...       ...       ...
# REV__Q9BXX2                               NaN         NaN    2.5494  0.006241
# REV__Q9P2G3                               NaN         NaN   -2.0000  1.000000
# S5FLF7                                    NaN        APOB  323.3100  0.000000
# S6AWD3                                    NaN         NaN    3.0695  0.002041
# S6AWD6                                    NaN         NaN   96.0170  0.000000
# S6BGF9                                    176         NaN   -2.0000  1.000000
# S6AWF4                                    NaN         NaN   26.8620  0.000000
# S6B291                                    267         NaN  107.6300  0.000000
# S6B294                                    NaN         NaN   40.0480  0.000000
# S6B2A6                                    275         NaN    3.8904  0.001097
# S6BAM6                                    275         NaN   47.4940  0.000000
# S6BAR0                                    179         NaN    3.2829  0.001554
# S6BGD6                                    179         NaN   -2.0000  1.000000
# S6BGE0                                    270         NaN   29.7310  0.000000
# S6BGE9                                    NaN         NaN    4.4306  0.001146
# S6BGF5                                    NaN         NaN   46.6650  0.000000
# S6C4Q7                                    271         NaN   -2.0000  1.000000
# S6C4Q9                                    134         NaN   -2.0000  1.000000
# S6C4R2                                    NaN         NaN   12.7490  0.000000
# S6C4R7                                    205         NaN    3.4694  0.001579
# S6C4S0                                    NaN         NaN   38.6760  0.000000
# S6C4S4                                    NaN         VH3   20.1000  0.000000
# U3KQE5                                    NaN        HBP1    2.5999  0.005299
# U3PXP0                                    NaN        HBA2    2.6697  0.004373
# U5LKG0                                    NaN       APOL1   -2.0000  1.000000
# V9GYM3                                     86       APOA2  323.3100  0.000000
# V9HW25                                    NaN   HEL-S-273    3.8731  0.001094
# V9HW34                                    170     HEL-213   10.0930  0.000000
# V9HW68                                    271     HEL-214  323.3100  0.000000
# X2L7S8                                    NaN       HLA-A   67.0060  0.000000
#
#                       LFQ intensity 22  LFQ intensity 23  LFQ intensity 20  \
# Majority protein IDs
# P01911                             NaN               NaN               NaN
# P05121                             NaN               NaN               NaN
# P55083                             NaN               NaN               NaN
# P09972                             NaN               NaN               NaN
# Q96C19                             NaN               NaN               NaN
# P37198                             NaN               NaN               NaN
# Q96A32                             NaN               NaN               NaN
# P55899                             NaN               NaN               NaN
# P35749                             NaN               NaN               NaN
# P06493                             NaN               NaN               NaN
# A0A024QZL1                         NaN               NaN               NaN
# P18206                        8.307368          8.520143          7.783854
# Q8IWL2                             NaN               NaN               NaN
# P07602                             NaN          7.351816               NaN
# P16083                             NaN               NaN               NaN
# Q8NBS9                             NaN               NaN               NaN
# P35237                             NaN               NaN               NaN
# P33778                             NaN               NaN               NaN
# Q6FI13                             NaN               NaN               NaN
# O15117                             NaN               NaN               NaN
# P02748                        9.685258          9.832764          9.550864
# Q8WVV5                             NaN               NaN               NaN
# Q9NS62                             NaN               NaN               NaN
# Q9BRK5                             NaN               NaN               NaN
# P09603                             NaN               NaN               NaN
# O43865                             NaN               NaN               NaN
# P52907                             NaN               NaN               NaN
# P06731                             NaN               NaN               NaN
# P01137                             NaN               NaN               NaN
# Q8IV08                             NaN               NaN               NaN
# ...                                ...               ...               ...
# REV__Q9BXX2                        NaN               NaN               NaN
# REV__Q9P2G3                        NaN               NaN               NaN
# S5FLF7                             NaN               NaN               NaN
# S6AWD3                             NaN               NaN               NaN
# S6AWD6                             NaN               NaN               NaN
# S6BGF9                             NaN               NaN               NaN
# S6AWF4                        9.727810          9.579509          9.517974
# S6B291                             NaN               NaN               NaN
# S6B294                        7.982149          7.785038          7.683425
# S6B2A6                        8.686019          8.479647          8.260453
# S6BAM6                        8.340940          8.152288          8.024486
# S6BAR0                        8.277357          8.480409          7.931737
# S6BGD6                             NaN          7.560922          7.665609
# S6BGE0                        9.039136          9.132928          9.219585
# S6BGE9                        7.991784          8.014667          7.406693
# S6BGF5                             NaN               NaN               NaN
# S6C4Q7                             NaN               NaN               NaN
# S6C4Q9                             NaN               NaN               NaN
# S6C4R2                        7.364551               NaN               NaN
# S6C4R7                             NaN               NaN               NaN
# S6C4S0                             NaN               NaN               NaN
# S6C4S4                             NaN          7.652720               NaN
# U3KQE5                             NaN               NaN               NaN
# U3PXP0                             NaN               NaN               NaN
# U5LKG0                             NaN               NaN               NaN
# V9GYM3                       10.474304         10.498931         10.444342
# V9HW25                             NaN               NaN               NaN
# V9HW34                             NaN               NaN               NaN
# V9HW68                       11.155882         11.067368         10.987568
# X2L7S8                             NaN               NaN               NaN
#
#                       LFQ intensity 21  LFQ intensity 26  LFQ intensity 27  \
# Majority protein IDs
# P01911                             NaN               NaN               NaN
# P05121                             NaN          6.966038               NaN
# P55083                             NaN               NaN               NaN
# P09972                        7.938540               NaN          8.006552
# Q96C19                             NaN               NaN               NaN
# P37198                             NaN               NaN               NaN
# Q96A32                             NaN               NaN               NaN
# P55899                             NaN               NaN               NaN
# P35749                             NaN               NaN               NaN
# P06493                             NaN               NaN               NaN
# A0A024QZL1                         NaN               NaN               NaN
# P18206                        8.989628          8.124470          8.492914
# Q8IWL2                             NaN               NaN               NaN
# P07602                        7.249834          7.360006               NaN
# P16083                             NaN               NaN               NaN
# Q8NBS9                             NaN               NaN               NaN
# P35237                             NaN               NaN               NaN
# P33778                             NaN               NaN               NaN
# Q6FI13                             NaN               NaN               NaN
# O15117                             NaN               NaN               NaN
# P02748                        9.798927          9.634930          9.733173
# Q8WVV5                             NaN               NaN               NaN
# Q9NS62                             NaN               NaN               NaN
# Q9BRK5                             NaN               NaN               NaN
# P09603                             NaN               NaN               NaN
# O43865                             NaN               NaN               NaN
# P52907                             NaN               NaN               NaN
# P06731                             NaN               NaN               NaN
# P01137                             NaN               NaN               NaN
# Q8IV08                             NaN               NaN               NaN
# ...                                ...               ...               ...
# REV__Q9BXX2                        NaN               NaN               NaN
# REV__Q9P2G3                        NaN               NaN               NaN
# S5FLF7                             NaN          8.705582          8.625454
# S6AWD3                             NaN               NaN               NaN
# S6AWD6                        7.648840          7.705018               NaN
# S6BGF9                             NaN               NaN               NaN
# S6AWF4                        9.694175          9.864191          9.676511
# S6B291                             NaN               NaN               NaN
# S6B294                        7.698231          7.913507               NaN
# S6B2A6                        8.817942          8.596597          8.724816
# S6BAM6                        8.206529          8.390228          8.190220
# S6BAR0                        8.289500          8.207715          8.137006
# S6BGD6                        8.035532          7.713919          7.672717
# S6BGE0                             NaN          9.689166               NaN
# S6BGE9                        7.812105          7.709931          7.515516
# S6BGF5                             NaN               NaN               NaN
# S6C4Q7                             NaN               NaN               NaN
# S6C4Q9                             NaN               NaN               NaN
# S6C4R2                             NaN               NaN               NaN
# S6C4R7                             NaN               NaN               NaN
# S6C4S0                             NaN               NaN               NaN
# S6C4S4                        7.488847          7.720374               NaN
# U3KQE5                             NaN               NaN               NaN
# U3PXP0                             NaN               NaN               NaN
# U5LKG0                             NaN               NaN               NaN
# V9GYM3                       10.454631         10.539841         10.395047
# V9HW25                             NaN               NaN               NaN
# V9HW34                             NaN               NaN               NaN
# V9HW68                       11.083718         11.186193         10.924186
# X2L7S8                             NaN               NaN               NaN
#
#                             ...         Intensity 76  Intensity 77  \
# Majority protein IDs        ...
# P01911                      ...                  NaN           NaN
# P05121                      ...                  NaN           NaN
# P55083                      ...                  NaN           NaN
# P09972                      ...             7.986825      8.097951
# Q96C19                      ...                  NaN      5.571441
# P37198                      ...                  NaN           NaN
# Q96A32                      ...                  NaN           NaN
# P55899                      ...                  NaN           NaN
# P35749                      ...                  NaN      8.007662
# P06493                      ...             5.947086           NaN
# A0A024QZL1                  ...             6.690736      7.246745
# P18206                      ...             8.419146      8.148603
# Q8IWL2                      ...                  NaN           NaN
# P07602                      ...             7.321847           NaN
# P16083                      ...                  NaN           NaN
# Q8NBS9                      ...             5.180470      6.330576
# P35237                      ...                  NaN      6.087071
# P33778                      ...                  NaN           NaN
# Q6FI13                      ...             6.084541      6.150095
# O15117                      ...                  NaN      6.937408
# P02748                      ...             9.618717      9.554174
# Q8WVV5                      ...                  NaN           NaN
# Q9NS62                      ...                  NaN           NaN
# Q9BRK5                      ...                  NaN           NaN
# P09603                      ...             6.172720      5.417671
# O43865                      ...                  NaN           NaN
# P52907                      ...             5.733001           NaN
# P06731                      ...                  NaN           NaN
# P01137                      ...                  NaN           NaN
# Q8IV08                      ...             6.601332           NaN
# ...                         ...                  ...           ...
# REV__Q9BXX2                 ...                  NaN      6.467904
# REV__Q9P2G3                 ...                  NaN           NaN
# S5FLF7                      ...             8.377270      5.962308
# S6AWD3                      ...             8.048170      8.377907
# S6AWD6                      ...             7.106769      7.704498
# S6BGF9                      ...             8.658269      8.785031
# S6AWF4                      ...             9.662087      9.810978
# S6B291                      ...             9.276301      9.516522
# S6B294                      ...             7.710642      7.995359
# S6B2A6                      ...             8.814061      8.796061
# S6BAM6                      ...             8.116541      7.837885
# S6BAR0                      ...             8.589693      8.496030
# S6BGD6                      ...             7.482559      7.893934
# S6BGE0                      ...             9.501771      9.660296
# S6BGE9                      ...             7.738487      7.753307
# S6BGF5                      ...             7.781087      7.547233
# S6C4Q7                      ...             5.724055           NaN
# S6C4Q9                      ...             8.042195      7.731871
# S6C4R2                      ...             6.746175      7.267852
# S6C4R7                      ...                  NaN      8.080716
# S6C4S0                      ...             7.523226      7.661576
# S6C4S4                      ...             7.823943      7.962492
# U3KQE5                      ...             7.279137      7.286860
# U3PXP0                      ...                  NaN           NaN
# U5LKG0                      ...                  NaN           NaN
# V9GYM3                      ...            10.437005     10.411788
# V9HW25                      ...                  NaN           NaN
# V9HW34                      ...             8.715502      8.818642
# V9HW68                      ...            11.214446     11.231470
# X2L7S8                      ...             6.705881      6.690435
#
#                       LFQ intensity 17  LFQ intensity 16  LFQ intensity 15  \
# Majority protein IDs
# P01911                             NaN               NaN               NaN
# P05121                             NaN               NaN               NaN
# P55083                             NaN               NaN               NaN
# P09972                             NaN               NaN          7.666106
# Q96C19                             NaN               NaN               NaN
# P37198                             NaN               NaN               NaN
# Q96A32                             NaN               NaN               NaN
# P55899                             NaN               NaN               NaN
# P35749                             NaN               NaN          7.426544
# P06493                             NaN               NaN               NaN
# A0A024QZL1                         NaN               NaN               NaN
# P18206                        8.390529          8.055722          8.344707
# Q8IWL2                             NaN               NaN               NaN
# P07602                        7.447732               NaN          7.176554
# P16083                             NaN               NaN               NaN
# Q8NBS9                             NaN               NaN               NaN
# P35237                             NaN               NaN               NaN
# P33778                             NaN               NaN               NaN
# Q6FI13                             NaN               NaN               NaN
# O15117                             NaN               NaN               NaN
# P02748                        9.749976          9.817433          9.669401
# Q8WVV5                             NaN               NaN               NaN
# Q9NS62                             NaN               NaN               NaN
# Q9BRK5                             NaN               NaN               NaN
# P09603                             NaN               NaN               NaN
# O43865                             NaN               NaN               NaN
# P52907                             NaN               NaN               NaN
# P06731                             NaN               NaN               NaN
# P01137                             NaN               NaN               NaN
# Q8IV08                             NaN               NaN               NaN
# ...                                ...               ...               ...
# REV__Q9BXX2                        NaN               NaN               NaN
# REV__Q9P2G3                        NaN               NaN               NaN
# S5FLF7                             NaN               NaN               NaN
# S6AWD3                             NaN               NaN               NaN
# S6AWD6                        7.621305          7.402485          7.326356
# S6BGF9                             NaN               NaN               NaN
# S6AWF4                        9.733951          9.532767          9.635081
# S6B291                             NaN               NaN               NaN
# S6B294                        7.785237          7.934816          7.974604
# S6B2A6                        8.667201          8.727676          8.440516
# S6BAM6                        8.355516          8.292949          8.425990
# S6BAR0                        8.323644          8.237254          8.194314
# S6BGD6                        8.164858          7.775530               NaN
# S6BGE0                        9.458348          9.106463               NaN
# S6BGE9                        8.005481          7.876779          7.528878
# S6BGF5                             NaN               NaN               NaN
# S6C4Q7                             NaN               NaN               NaN
# S6C4Q9                             NaN               NaN               NaN
# S6C4R2                             NaN               NaN               NaN
# S6C4R7                             NaN               NaN               NaN
# S6C4S0                             NaN               NaN               NaN
# S6C4S4                             NaN               NaN          7.844067
# U3KQE5                             NaN               NaN               NaN
# U3PXP0                             NaN               NaN               NaN
# U5LKG0                             NaN               NaN               NaN
# V9GYM3                       10.389857         10.548439         10.497924
# V9HW25                             NaN               NaN               NaN
# V9HW34                             NaN               NaN               NaN
# V9HW68                       11.120607         11.072250         11.155913
# X2L7S8                             NaN               NaN               NaN
#
#                       LFQ intensity 14  LFQ intensity 13  LFQ intensity 12  \
# Majority protein IDs
# P01911                             NaN               NaN               NaN
# P05121                             NaN               NaN               NaN
# P55083                             NaN               NaN               NaN
# P09972                             NaN          7.580788               NaN
# Q96C19                        6.015402               NaN               NaN
# P37198                             NaN               NaN               NaN
# Q96A32                             NaN          6.381115               NaN
# P55899                             NaN               NaN               NaN
# P35749                             NaN               NaN               NaN
# P06493                             NaN               NaN               NaN
# A0A024QZL1                         NaN               NaN               NaN
# P18206                        8.609573          8.063408          8.206961
# Q8IWL2                             NaN               NaN               NaN
# P07602                             NaN               NaN               NaN
# P16083                             NaN               NaN               NaN
# Q8NBS9                             NaN               NaN               NaN
# P35237                             NaN               NaN               NaN
# P33778                             NaN               NaN               NaN
# Q6FI13                             NaN               NaN               NaN
# O15117                             NaN               NaN               NaN
# P02748                        9.864060          9.866512          9.657104
# Q8WVV5                             NaN               NaN               NaN
# Q9NS62                             NaN               NaN               NaN
# Q9BRK5                             NaN               NaN               NaN
# P09603                             NaN               NaN               NaN
# O43865                             NaN               NaN               NaN
# P52907                             NaN               NaN               NaN
# P06731                             NaN               NaN               NaN
# P01137                             NaN               NaN               NaN
# Q8IV08                             NaN               NaN               NaN
# ...                                ...               ...               ...
# REV__Q9BXX2                        NaN               NaN               NaN
# REV__Q9P2G3                        NaN               NaN               NaN
# S5FLF7                             NaN               NaN               NaN
# S6AWD3                             NaN               NaN               NaN
# S6AWD6                             NaN               NaN               NaN
# S6BGF9                             NaN               NaN               NaN
# S6AWF4                        9.207311          9.566732          9.416174
# S6B291                             NaN               NaN               NaN
# S6B294                             NaN          7.889823          7.638948
# S6B2A6                        8.198782          8.376157          8.806132
# S6BAM6                        8.713415          8.221936          8.399016
# S6BAR0                        7.786748          8.383438          8.234036
# S6BGD6                             NaN          7.938265          7.808609
# S6BGE0                             NaN          9.395222               NaN
# S6BGE9                        7.740521          8.033021          7.640680
# S6BGF5                             NaN               NaN               NaN
# S6C4Q7                             NaN               NaN               NaN
# S6C4Q9                             NaN               NaN               NaN
# S6C4R2                             NaN               NaN               NaN
# S6C4R7                             NaN               NaN               NaN
# S6C4S0                             NaN               NaN               NaN
# S6C4S4                             NaN               NaN          7.747054
# U3KQE5                             NaN               NaN               NaN
# U3PXP0                             NaN               NaN               NaN
# U5LKG0                             NaN               NaN               NaN
# V9GYM3                       10.507923         10.541716         10.482716
# V9HW25                             NaN               NaN               NaN
# V9HW34                             NaN               NaN               NaN
# V9HW68                       11.529174         11.020817         10.989414
# X2L7S8                             NaN               NaN               NaN
#
#                       LFQ intensity 11  LFQ intensity 10
# Majority protein IDs
# P01911                             NaN               NaN
# P05121                             NaN               NaN
# P55083                             NaN               NaN
# P09972                             NaN               NaN
# Q96C19                             NaN               NaN
# P37198                             NaN               NaN
# Q96A32                             NaN               NaN
# P55899                             NaN               NaN
# P35749                             NaN               NaN
# P06493                             NaN               NaN
# A0A024QZL1                         NaN               NaN
# P18206                        8.219165          8.385660
# Q8IWL2                             NaN               NaN
# P07602                             NaN               NaN
# P16083                             NaN               NaN
# Q8NBS9                             NaN               NaN
# P35237                             NaN               NaN
# P33778                             NaN               NaN
# Q6FI13                             NaN               NaN
# O15117                             NaN               NaN
# P02748                        9.831390          9.807251
# Q8WVV5                        5.625199               NaN
# Q9NS62                             NaN               NaN
# Q9BRK5                             NaN               NaN
# P09603                             NaN               NaN
# O43865                             NaN               NaN
# P52907                             NaN               NaN
# P06731                             NaN               NaN
# P01137                             NaN               NaN
# Q8IV08                             NaN               NaN
# ...                                ...               ...
# REV__Q9BXX2                        NaN               NaN
# REV__Q9P2G3                        NaN               NaN
# S5FLF7                             NaN               NaN
# S6AWD3                             NaN               NaN
# S6AWD6                        7.283075          7.575188
# S6BGF9                             NaN               NaN
# S6AWF4                        9.160025          9.659717
# S6B291                             NaN               NaN
# S6B294                        7.908222               NaN
# S6B2A6                        8.279439          8.809846
# S6BAM6                        8.308522          8.363612
# S6BAR0                        8.187577          8.339074
# S6BGD6                        7.905288          8.040286
# S6BGE0                             NaN               NaN
# S6BGE9                        7.907395          8.053625
# S6BGF5                             NaN               NaN
# S6C4Q7                             NaN               NaN
# S6C4Q9                             NaN               NaN
# S6C4R2                             NaN               NaN
# S6C4R7                             NaN               NaN
# S6C4S0                             NaN               NaN
# S6C4S4                        7.801863          7.684945
# U3KQE5                             NaN               NaN
# U3PXP0                             NaN               NaN
# U5LKG0                             NaN               NaN
# V9GYM3                       10.435924         10.515900
# V9HW25                             NaN               NaN
# V9HW34                             NaN               NaN
# V9HW68                       11.067443         11.192902
# X2L7S8                             NaN               NaN
#
# [2295 rows x 158 columns]

# %%
extractModificationProteinSubjectRelationships(data)
# Out:
#                      Glycation site positions
# Majority protein IDs
# P01911                                    NaN
# P05121                                    NaN
# P55083                                    NaN
# P09972                                    NaN
# Q96C19                                    NaN
# P37198                                    NaN
# Q96A32                                    NaN
# P55899                                    NaN
# P35749                                    NaN
# P06493                                    NaN
# A0A024QZL1                                NaN
# P18206                                    NaN
# Q8IWL2                                    NaN
# P07602                                    NaN
# P16083                                    NaN
# Q8NBS9                                    NaN
# P35237                                    NaN
# P33778                                    NaN
# Q6FI13                                    NaN
# O15117                                    NaN
# P02748                                    NaN
# Q8WVV5                                    NaN
# Q9NS62                                    NaN
# Q9BRK5                                    NaN
# P09603                                    NaN
# O43865                                    NaN
# P52907                                    NaN
# P06731                                    NaN
# P01137                                    NaN
# Q8IV08                                    NaN
# ...                                       ...
# REV__Q9BXX2                               NaN
# REV__Q9P2G3                               NaN
# S5FLF7                                    NaN
# S6AWD3                                    NaN
# S6AWD6                                    NaN
# S6BGF9                                    176
# S6AWF4                                    NaN
# S6B291                                    267
# S6B294                                    NaN
# S6B2A6                                    275
# S6BAM6                                    275
# S6BAR0                                    179
# S6BGD6                                    179
# S6BGE0                                    270
# S6BGE9                                    NaN
# S6BGF5                                    NaN
# S6C4Q7                                    271
# S6C4Q9                                    134
# S6C4R2                                    NaN
# S6C4R7                                    205
# S6C4S0                                    NaN
# S6C4S4                                    NaN
# U3KQE5                                    NaN
# U3PXP0                                    NaN
# U5LKG0                                    NaN
# V9GYM3                                     86
# V9HW25                                    NaN
# V9HW34                                    170
# V9HW68                                    271
# X2L7S8                                    NaN
#
# [2295 rows x 1 columns]

# %%
aux
# Out:
#       :START_ID(Protein) :END_ID(Subject)  LFQ intensity
# 0                 P01911               78       6.437164
# 1                 P05121               26       6.966038
# 2                 P09972               21       7.938540
# 3                 P09972               27       8.006552
# 4                 P09972                1       8.062657
# 5                 P09972                7       7.916659
# 6                 P09972               41       7.782902
# 7                 P09972               46       8.062582
# 8                 P09972               74       8.332438
# 9                 P09972               77       8.065953
# 10                P09972               62       7.646090
# 11                P09972               57       7.758806
# 12                P09972               56       8.114944
# 13                P09972               18       7.853023
# 14                P09972               59       7.851772
# 15                P09972               15       7.666106
# 16                P09972               13       7.580788
# 17                Q96C19               14       6.015402
# 18                Q96A32               13       6.381115
# 19                P55899               19       5.803983
# 20                P35749               15       7.426544
# 21                P06493               76       5.968679
# 22            A0A024QZL1               28       7.383528
# 23            A0A024QZL1               31       7.043716
# 24            A0A024QZL1               45       7.031772
# 25                P18206               22       8.307368
# 26                P18206               23       8.520143
# 27                P18206               20       7.783854
# 28                P18206               21       8.989628
# 29                P18206               26       8.124470
# ...                  ...              ...            ...
# 38815             V9HW68               67      10.975156
# 38816             V9HW68               64      11.052463
# 38817             V9HW68               65      11.060962
# 38818             V9HW68               62      11.089092
# 38819             V9HW68               63      11.091632
# 38820             V9HW68               60      11.078819
# 38821             V9HW68               76      11.195844
# 38822             V9HW68               61      11.100336
# 38823             V9HW68               78      11.012753
# 38824             V9HW68               68      11.111968
# 38825             V9HW68               35      11.139092
# 38826             V9HW68               34      11.019241
# 38827             V9HW68               69      11.073205
# 38828             V9HW68               57      11.058312
# 38829             V9HW68               56      11.117238
# 38830             V9HW68               19      11.100750
# 38831             V9HW68               39      11.136023
# 38832             V9HW68               18      11.072066
# 38833             V9HW68               38      11.158332
# 38834             V9HW68               59      11.121921
# 38835             V9HW68               58      10.994414
# 38836             V9HW68               17      11.120607
# 38837             V9HW68               16      11.072250
# 38838             V9HW68               15      11.155913
# 38839             V9HW68               14      11.529174
# 38840             V9HW68               13      11.020817
# 38841             V9HW68               12      10.989414
# 38842             V9HW68               11      11.067443
# 38843             V9HW68               10      11.192902
# 38844             X2L7S8                9       6.626227
#
# [38845 rows x 3 columns]
